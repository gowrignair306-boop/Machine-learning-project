# %% [markdown]
# <a href="https://colab.research.google.com/github/gowrignair306-boop/Machine-learning-project/blob/main/Day_2_NumPy_and_Pndas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#load dataset
df=sns.load_dataset("titanic")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.shape
# Out:
# (891, 15)

# %%
df.size
# Out:
# 13365

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
#checking missing values
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.shape
# Out:
# (891, 15)

# %%
df_clean=df.drop(columns=['deck'])
df_clean #column remove
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
#null values inside the column
df.dropna(subset=['embarked','embark_town'],inplace=True)
print(df.isnull().sum())
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      0
# alive            0
# alone            0
# dtype: int64

# %%
#filling numerical values with mean
age_mean=df['age'].mean()
df['age']=df['age'].fillna(age_mean)

# %%
#create a column family_size:
df['family_size']=df['sibsp']+df['parch']
#create age_group column:
df['age_group']=np.where(df['age']<18,"Child","Adult")

# %%
#create column fare_per_person
df['fare_per_person']=df['fare']/(df['family_size']+1)

# %%
df.rename(columns={'pclass':'Passenger_class'},inplace=True)
df
# Out:
#      survived  Passenger_class     sex        age  sibsp  parch     fare  \
# 0           0                3    male  22.000000      1      0   7.2500
# 1           1                1  female  38.000000      1      0  71.2833
# 2           1                3  female  26.000000      0      0   7.9250
# 3           1                1  female  35.000000      1      0  53.1000
# 4           0                3    male  35.000000      0      0   8.0500
# ..        ...              ...     ...        ...    ...    ...      ...
# 886         0                2    male  27.000000      0      0  13.0000
# 887         1                1  female  19.000000      0      0  30.0000
# 888         0                3  female  29.642093      1      2  23.4500
# 889         1                1    male  26.000000      0      0  30.0000
# 890         0                3    male  32.000000      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone  \
# ...

# %%
#Passengers older than average age
df[df['age']>df['age'].mean()]
# Out:
#      survived  Passenger_class     sex   age  sibsp  parch     fare embarked  \
# 1           1                1  female  38.0      1      0  71.2833        C
# 3           1                1  female  35.0      1      0  53.1000        S
# 4           0                3    male  35.0      0      0   8.0500        S
# 6           0                1    male  54.0      0      0  51.8625        S
# 11          1                1  female  58.0      0      0  26.5500        S
# ..        ...              ...     ...   ...    ...    ...      ...      ...
# 873         0                3    male  47.0      0      0   9.0000        S
# 879         1                1  female  56.0      0      1  83.1583        C
# 881         0                3    male  33.0      0      0   7.8958        S
# 885         0                3  female  39.0      0      5  29.1250        Q
# 890         0                3    male  32.0      0      0   7.7500        Q
#
# ...

# %%
#Female passengers in first class
df[(df['sex']=='female')& (df['Passenger_class']==1)]
# Out:
#      survived  Passenger_class     sex        age  sibsp  parch      fare  \
# 1           1                1  female  38.000000      1      0   71.2833
# 3           1                1  female  35.000000      1      0   53.1000
# 11          1                1  female  58.000000      0      0   26.5500
# 31          1                1  female  29.642093      1      0  146.5208
# 52          1                1  female  49.000000      1      0   76.7292
# ..        ...              ...     ...        ...    ...    ...       ...
# 856         1                1  female  45.000000      1      1  164.8667
# 862         1                1  female  48.000000      0      0   25.9292
# 871         1                1  female  47.000000      1      1   52.5542
# 879         1                1  female  56.000000      0      1   83.1583
# 887         1                1  female  19.000000      0      0   30.0000
#
#     embarked  class    who  adult_male deck  embark_town alive  alone  \
# ...

# %%
df1=sns.load_dataset("penguins")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df1.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df1.shape
# Out:
# (344, 7)

# %%
df1.size
# Out:
# 2408

# %%
df1.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
df1.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
#checking missing values
df1.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
#null values inside the column
df1.dropna(subset=['bill_length_mm','flipper_length_mm'],inplace=True)
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
#filling numerical values with mean
bill_length_mean=df['bill_length_mm'].mean()
df['bill_length_mm']=df['bill_length_mm'].fillna(bill_length_mean)
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen        39.10000           18.7              181.0
# 1    Adelie  Torgersen        39.50000           17.4              186.0
# 2    Adelie  Torgersen        40.30000           18.0              195.0
# 3    Adelie  Torgersen        43.92193            NaN                NaN
# 4    Adelie  Torgersen        36.70000           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe        43.92193            NaN                NaN
# 340  Gentoo     Biscoe        46.80000           14.3              215.0
# 341  Gentoo     Biscoe        50.40000           15.7              222.0
# 342  Gentoo     Biscoe        45.20000           14.8              212.0
# 343  Gentoo     Biscoe        49.90000           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
bill_depth_mean=df['bill_depth_mm'].mean()
df['bill_depth_mm']=df['bill_depth_mm'].fillna(bill_depth_mean)
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen        39.10000       18.70000              181.0
# 1    Adelie  Torgersen        39.50000       17.40000              186.0
# 2    Adelie  Torgersen        40.30000       18.00000              195.0
# 3    Adelie  Torgersen        43.92193       17.15117                NaN
# 4    Adelie  Torgersen        36.70000       19.30000              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe        43.92193       17.15117                NaN
# 340  Gentoo     Biscoe        46.80000       14.30000              215.0
# 341  Gentoo     Biscoe        50.40000       15.70000              222.0
# 342  Gentoo     Biscoe        45.20000       14.80000              212.0
# 343  Gentoo     Biscoe        49.90000       16.10000              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
#filling the numeric value using median
bill_length_median=df['bill_length_mm'].median()
df['bill_length_mm']=df['bill_length_mm'].fillna(bill_length_median)
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen        39.10000       18.70000              181.0
# 1    Adelie  Torgersen        39.50000       17.40000              186.0
# 2    Adelie  Torgersen        40.30000       18.00000              195.0
# 3    Adelie  Torgersen        43.92193       17.15117                NaN
# 4    Adelie  Torgersen        36.70000       19.30000              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe        43.92193       17.15117                NaN
# 340  Gentoo     Biscoe        46.80000       14.30000              215.0
# 341  Gentoo     Biscoe        50.40000       15.70000              222.0
# 342  Gentoo     Biscoe        45.20000       14.80000              212.0
# 343  Gentoo     Biscoe        49.90000       16.10000              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df1['bill_ratio']=df1['bill_length_mm']/df1['bill_depth_mm']
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  bill_ratio
# 0         3750.0    Male    2.090909
# ...

# %%
df1.rename(columns={'bill_length_mm':'bill_length'},inplace=True)
df1
# Out:
#     species     island  bill_length  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen         39.1           18.7              181.0
# 1    Adelie  Torgersen         39.5           17.4              186.0
# 2    Adelie  Torgersen         40.3           18.0              195.0
# 4    Adelie  Torgersen         36.7           19.3              193.0
# 5    Adelie  Torgersen         39.3           20.6              190.0
# ..      ...        ...          ...            ...                ...
# 338  Gentoo     Biscoe         47.2           13.7              214.0
# 340  Gentoo     Biscoe         46.8           14.3              215.0
# 341  Gentoo     Biscoe         50.4           15.7              222.0
# 342  Gentoo     Biscoe         45.2           14.8              212.0
# 343  Gentoo     Biscoe         49.9           16.1              213.0
#
#      body_mass_g     sex  bill_ratio
# 0         3750.0    Male    2.090909
# 1         3800.0  Female    2.270115
# ...

# %%
df1['body_mass_g']>df1['body_mass_g'].mean()
# Out:
# 0      False
# 1      False
# 2      False
# 4      False
# 5      False
#        ...
# 338     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: body_mass_g, Length: 342, dtype: bool

# %%
df1[(df1['sex']=='Female')&(df1['flipper_length_mm']>200)]
# Out:
#        species  island  bill_length  bill_depth_mm  flipper_length_mm  \
# 90      Adelie   Dream         35.7           18.0              202.0
# 216  Chinstrap   Dream         43.5           18.1              202.0
# 220     Gentoo  Biscoe         46.1           13.2              211.0
# 222     Gentoo  Biscoe         48.7           14.1              210.0
# 225     Gentoo  Biscoe         46.5           13.5              210.0
# 226     Gentoo  Biscoe         45.4           14.6              211.0
# 228     Gentoo  Biscoe         43.3           13.4              209.0
# 230     Gentoo  Biscoe         40.9           13.7              214.0
# 232     Gentoo  Biscoe         45.5           13.7              214.0
# 234     Gentoo  Biscoe         45.8           14.6              210.0
# 236     Gentoo  Biscoe         42.0           13.5              210.0
# 238     Gentoo  Biscoe         46.2           14.5              209.0
# ...

# %%
df1.groupby('sex')['bill_ratio'].mean()
# Out:
# sex
# Female    2.609508
# Male      2.604988
# Name: bill_ratio, dtype: float64

# %%
df1.groupby('species')['flipper_length_mm'].mean()
# Out:
# species
# Adelie       189.953642
# Chinstrap    195.823529
# Gentoo       217.186992
# Name: flipper_length_mm, dtype: float64

# %%
df1.corr(numeric_only=True)
# Out:
#                    bill_length  bill_depth_mm  flipper_length_mm  body_mass_g  \
# bill_length           1.000000      -0.235053           0.656181     0.595110
# bill_depth_mm        -0.235053       1.000000          -0.583851    -0.471916
# flipper_length_mm     0.656181      -0.583851           1.000000     0.871202
# body_mass_g           0.595110      -0.471916           0.871202     1.000000
# bill_ratio            0.780396      -0.784191           0.805166     0.703119
#
#                    bill_ratio
# bill_length          0.780396
# bill_depth_mm       -0.784191
# flipper_length_mm    0.805166
# body_mass_g          0.703119
# bill_ratio           1.000000
